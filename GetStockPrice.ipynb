# %% [markdown]
# # Sample Result from API:
#
# {
#     "Global Quote": {
#         "01. symbol": "542752.BSE",
#         "02. open": "1085.0000",
#         "03. high": "1100.9500",
#         "04. low": "1081.2500",
#         "05. price": "1084.4500",
#         "06. volume": "9102",
#         "07. latest trading day": "2021-12-08",
#         "08. previous close": "1079.6000",
#         "09. change": "4.8500",
#         "10. change percent": "0.4492%"
#     }
# }

# %%
import requests
import time

symbols = [
{'symbol': '542752.BSE', 'company': 'Affle India Ltd.'},
{'symbol': 'AMARAJABAT.BSE', 'company': 'Amara Raja Batteries'},
{'symbol': '533271.BSE', 'company': 'Ashoka Buildcon'},
{'symbol': 'ASIANPAINT.BSE', 'company': 'Asian Paints'},
{'symbol': '500020.BSE', 'company': 'Bombay Dyeing'},
{'symbol': 'BPCL.BSE', 'company': 'BPCL'},
{'symbol': '500183.BSE', 'company': 'HFCL'},
{'symbol': '540750.BSE', 'company': 'IEX'},
{'symbol': 'INFY.BSE', 'company': 'Infosys'},
{'symbol': '541956.BSE', 'company': 'IRCON'},
{'symbol': 'IRCTC.BSE', 'company': 'IRCTC'},
{'symbol': 'JSWSTEEL.BSE', 'company': 'JSW Steel'},
{'symbol': 'LAURUSLABS.BSE', 'company': 'Laurus Labs'},
{'symbol': 'MHRIL.BSE', 'company': 'MHRIL'},
{'symbol': '532539.BSE', 'company': 'Minda Industries'},
{'symbol': '517334.BSE', 'company': 'Motherson Sumi'},
{'symbol': 'NESTLEIND.BSE', 'company': 'Nestle India'},
{'symbol': '500331.BSE', 'company': 'Pidilite Industries'},
{'symbol': '532670.BSE', 'company': 'Shree Renuka Sugar'},
{'symbol': '500408.BSE', 'company': 'Tata ELXSI'},
{'symbol': '500400.BSE', 'company': 'Tata Power'},
{'symbol': 'TATASTEEL.BSE', 'company': 'Tata Steel'},
{'symbol': 'TRIDENT.BSE', 'company': 'Trident'},
{'symbol': 'SBICARD.BSE', 'company': 'SBI Cards'},
{'symbol': 'RPOWER.BSE', 'company': 'Reliance Power'},
{'symbol': 'JAICORPLTD.BSE', 'company': 'Jai Corp'},
{'symbol': '542867.BSE', 'company': 'CSB Bank Ltd'},
{'symbol': '542649.BSE', 'company': 'RVNL'},
{'symbol': '517506.BSE', 'company': 'TTK Prestige Ltd.'}
]

count = 0
stockData = []
for symbol in symbols:
    count += 1
    #print('(', count, ')', 'Getting data for: ', symbol['company'], symbol['symbol'])
    print(f"({count}) Getting data for: {symbol['company']} ({symbol['symbol']})")
    # replace the "demo" apikey below with your own key from https://www.alphavantage.co/support/#api-key
    url = 'https://www.alphavantage.co/query?function=GLOBAL_QUOTE&symbol=' + symbol['symbol'] + '&apikey=2K30K29WEZ1S23Z'
    r = requests.get(url)
    data = r.json()
    
    import json

    dataDump = json.dumps(data)
    #print(dataDump)
    
    stockDetails = json.loads(dataDump)
    print(stockDetails)

    (stock, price)  = (stockDetails['Global Quote']['01. symbol'], stockDetails['Global Quote']['05. price'])
    date = stockDetails['Global Quote']['07. latest trading day']
    print(stock, price)
    

    stockData.append({'company': symbol["company"], 'symbol': stock, 'date' : date, 'price': price})

    if(count % 5 == 0):
        print('Alpha Vantage allows only 5 calls a minute. So, wait...')
        time.sleep(62)
        

print(stockData)

import csv

filename = "C:\\temp\\stockprice.csv"
fields = ['company', 'symbol', 'date', 'price']
with open(filename, 'w', newline='') as csvfile: 
    # creating a csv dict writer object 
    writer = csv.DictWriter(csvfile, fieldnames = fields) 
        
    # writing headers (field names) 
    writer.writeheader() 
        
    # writing data rows 
    writer.writerows(stockData)
# Out:
# (1) Getting data for: Affle India Ltd. (542752.BSE)
# {'Global Quote': {'01. symbol': '542752.BSE', '02. open': '1083.0000', '03. high': '1119.0000', '04. low': '1069.2000', '05. price': '1102.8000', '06. volume': '36603', '07. latest trading day': '2021-12-29', '08. previous close': '1075.1000', '09. change': '27.7000', '10. change percent': '2.5765%'}}
# 542752.BSE 1102.8000
# (2) Getting data for: Amara Raja Batteries (AMARAJABAT.BSE)
# {'Global Quote': {'01. symbol': 'AMARAJABAT.BSE', '02. open': '629.8000', '03. high': '632.1500', '04. low': '621.2000', '05. price': '623.0000', '06. volume': '129494', '07. latest trading day': '2021-12-29', '08. previous close': '617.8000', '09. change': '5.2000', '10. change percent': '0.8417%'}}
# AMARAJABAT.BSE 623.0000
# (3) Getting data for: Ashoka Buildcon (533271.BSE)
# {'Global Quote': {'01. symbol': '533271.BSE', '02. open': '101.5000', '03. high': '101.5000', '04. low': '98.7500', '05. price': '99.5500', '06. volume': '134228', '07. latest trading day': '2021-12-29', '08. previous close': '98.5500', '09. change': '1.0000', '10. change percent': '1.0147%'}}
# 533271.BSE 99.5500
# (4) Getting data for: Asian Paints (ASIANPAINT.BSE)
# {'Global Quote': {'01. symbol': 'ASIANPAINT.BSE', '02. open': '3375.0000', '03. high': '3386.0000', '04. low': '3334.2000', '05. price': '3369.0000', '06. volume': '32020', '07. latest trading day': '2021-12-29', '08. previous close': '3367.1499', '09. change': '1.8501', '10. change percent': '0.0549%'}}
# ASIANPAINT.BSE 3369.0000
# (5) Getting data for: Bombay Dyeing (500020.BSE)
# {'Global Quote': {'01. symbol': '500020.BSE', '02. open': '113.1000', '03. high': '116.2000', '04. low': '107.5500', '05. price': '109.0000', '06. volume': '895491', '07. latest trading day': '2021-12-29', '08. previous close': '114.0500', '09. change': '-5.0500', '10. change percent': '-4.4279%'}}
# 500020.BSE 109.0000
# Alpha Vantage allows only 5 calls a minute. So, wait...
# (6) Getting data for: BPCL (BPCL.BSE)
# {'Global Quote': {'01. symbol': 'BPCL.BSE', '02. open': '380.4000', '03. high': '382.7000', '04. low': '377.2500', '05. price': '381.4500', '06. volume': '423554', '07. latest trading day': '2021-12-29', '08. previous close': '380.4000', '09. change': '1.0500', '10. change percent': '0.2760%'}}
# BPCL.BSE 381.4500
# (7) Getting data for: HFCL (500183.BSE)
# {'Global Quote': {'01. symbol': '500183.BSE', '02. open': '80.7000', '03. high': '81.7000', '04. low': '79.6500', '05. price': '80.3000', '06. volume': '889236', '07. latest trading day': '2021-12-29', '08. previous close': '80.5500', '09. change': '-0.2500', '10. change percent': '-0.3104%'}}
# 500183.BSE 80.3000
# (8) Getting data for: IEX (540750.BSE)
# {'Global Quote': {'01. symbol': '540750.BSE', '02. open': '255.9500', '03. high': '255.9500', '04. low': '250.6000', '05. price': '252.7000', '06. volume': '309378', '07. latest trading day': '2021-12-29', '08. previous close': '255.1500', '09. change': '-2.4500', '10. change percent': '-0.9602%'}}
# 540750.BSE 252.7000
# (9) Getting data for: Infosys (INFY.BSE)
# {'Global Quote': {'01. symbol': 'INFY.BSE', '02. open': '1884.9500', '03. high': '1893.2000', '04. low': '1876.6500', '05. price': '1885.0500', '06. volume': '165221', '07. latest trading day': '2021-12-29', '08. previous close': '1887.4500', '09. change': '-2.4000', '10. change percent': '-0.1272%'}}
# INFY.BSE 1885.0500
# (10) Getting data for: IRCON (541956.BSE)
# {'Global Quote': {'01. symbol': '541956.BSE', '02. open': '44.9000', '03. high': '45.1000', '04. low': '44.7000', '05. price': '44.8000', '06. volume': '135556', '07. latest trading day': '2021-12-29', '08. previous close': '44.9000', '09. change': '-0.1000', '10. change percent': '-0.2227%'}}
# 541956.BSE 44.8000
# Alpha Vantage allows only 5 calls a minute. So, wait...
