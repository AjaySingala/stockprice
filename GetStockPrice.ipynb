# %% [markdown]
# # Sample Result from API:
#
# {
#     "Global Quote": {
#         "01. symbol": "542752.BSE",
#         "02. open": "1085.0000",
#         "03. high": "1100.9500",
#         "04. low": "1081.2500",
#         "05. price": "1084.4500",
#         "06. volume": "9102",
#         "07. latest trading day": "2021-12-08",
#         "08. previous close": "1079.6000",
#         "09. change": "4.8500",
#         "10. change percent": "0.4492%"
#     }
# }

# %%
import requests
import time

symbols = [
{'symbol': '542752.BSE', 'company': 'Affle India Ltd.'},
{'symbol': 'AMARAJABAT.BSE', 'company': 'Amara Raja Batteries'},
{'symbol': '533271.BSE', 'company': 'Ashoka Buildcon'},
{'symbol': 'ASIANPAINT.BSE', 'company': 'Asian Paints'},
{'symbol': '500020.BSE', 'company': 'Bombay Dyeing'},
{'symbol': 'BPCL.BSE', 'company': 'BPCL'},
{'symbol': '500183.BSE', 'company': 'HFCL'},
{'symbol': '540750.BSE', 'company': 'IEX'},
{'symbol': 'INFY.BSE', 'company': 'Infosys'},
{'symbol': '541956.BSE', 'company': 'IRCON'},
{'symbol': '542830.BSE', 'company': 'IRCTC'},
{'symbol': 'JSWSTEEL.BSE', 'company': 'JSW Steel'},
{'symbol': '540222.BSE', 'company': 'Laurus Labs'},
{'symbol': 'MHRIL.BSE', 'company': 'MHRIL'},
{'symbol': '532539.BSE', 'company': 'Minda Industries'},
{'symbol': '517334.BSE', 'company': 'Motherson Sumi'},
{'symbol': 'NESTLEIND.BSE', 'company': 'Nestle India'},
{'symbol': '500331.BSE', 'company': 'Pidilite Industries'},
{'symbol': '542652.BSE', 'company': 'Polycab India Ltd.'},
{'symbol': '532670.BSE', 'company': 'Shree Renuka Sugar'},
{'symbol': '500408.BSE', 'company': 'Tata ELXSI'},
{'symbol': '500400.BSE', 'company': 'Tata Power'},
{'symbol': 'TATASTEEL.BSE', 'company': 'Tata Steel'},
{'symbol': 'TRIDENT.BSE', 'company': 'Trident'},
{'symbol': 'SBICARD.BSE', 'company': 'SBI Cards'},
{'symbol': 'RPOWER.BSE', 'company': 'Reliance Power'},
{'symbol': 'JAICORPLTD.BSE', 'company': 'Jai Corp'},
{'symbol': '542867.BSE', 'company': 'CSB Bank Ltd'},
{'symbol': '542649.BSE', 'company': 'RVNL'},
{'symbol': '517506.BSE', 'company': 'TTK Prestige Ltd.'}
]

count = 0
stockData = []
for symbol in symbols:
    count += 1
    #print('(', count, ')', 'Getting data for: ', symbol['company'], symbol['symbol'])
    print(f"({count}) Getting data for: {symbol['company']} ({symbol['symbol']})")
    # replace the "demo" apikey below with your own key from https://www.alphavantage.co/support/#api-key
    url = 'https://www.alphavantage.co/query?function=GLOBAL_QUOTE&symbol=' + symbol['symbol'] + '&apikey=2K30K29WEZ1S23Z'
    r = requests.get(url)
    data = r.json()
    
    import json

    dataDump = json.dumps(data)
    #print(dataDump)
    
    stockDetails = json.loads(dataDump)
    print(stockDetails)

    (stock, price)  = (stockDetails['Global Quote']['01. symbol'], stockDetails['Global Quote']['05. price'])
    date = stockDetails['Global Quote']['07. latest trading day']
    print(stock, price)
    

    stockData.append({'company': symbol["company"], 'symbol': stock, 'date' : date, 'price': price})

    if(count % 5 == 0):
        print('Alpha Vantage allows only 5 calls a minute. So, wait...')
        time.sleep(62)
        

print(stockData)

import csv

filename = "C:\\temp\\stockprice.csv"
fields = ['company', 'symbol', 'date', 'price']
with open(filename, 'w', newline='') as csvfile: 
    # creating a csv dict writer object 
    writer = csv.DictWriter(csvfile, fieldnames = fields) 
        
    # writing headers (field names) 
    writer.writeheader() 
        
    # writing data rows 
    writer.writerows(stockData)
# Out:
# (1) Getting data for: Affle India Ltd. (542752.BSE)
# {'Global Quote': {'01. symbol': '542752.BSE', '02. open': '1064.3000', '03. high': '1070.1000', '04. low': '1030.1000', '05. price': '1057.4000', '06. volume': '72759', '07. latest trading day': '2021-12-20', '08. previous close': '1081.8000', '09. change': '-24.4000', '10. change percent': '-2.2555%'}}
# 542752.BSE 1057.4000
# (2) Getting data for: Amara Raja Batteries (AMARAJABAT.BSE)
# {'Global Quote': {'01. symbol': 'AMARAJABAT.BSE', '02. open': '617.0000', '03. high': '617.4500', '04. low': '584.4500', '05. price': '591.5000', '06. volume': '186068', '07. latest trading day': '2021-12-20', '08. previous close': '618.5000', '09. change': '-27.0000', '10. change percent': '-4.3654%'}}
# AMARAJABAT.BSE 591.5000
# (3) Getting data for: Ashoka Buildcon (533271.BSE)
# {'Global Quote': {'01. symbol': '533271.BSE', '02. open': '92.3500', '03. high': '92.4000', '04. low': '87.5500', '05. price': '89.0500', '06. volume': '311924', '07. latest trading day': '2021-12-20', '08. previous close': '93.3000', '09. change': '-4.2500', '10. change percent': '-4.5552%'}}
# 533271.BSE 89.0500
# (4) Getting data for: Asian Paints (ASIANPAINT.BSE)
# {'Global Quote': {'01. symbol': 'ASIANPAINT.BSE', '02. open': '3239.0000', '03. high': '3262.3501', '04. low': '3180.8999', '05. price': '3240.0500', '06. volume': '75047', '07. latest trading day': '2021-12-20', '08. previous close': '3241.7000', '09. change': '-1.6500', '10. change percent': '-0.0509%'}}
# ASIANPAINT.BSE 3240.0500
# (5) Getting data for: Bombay Dyeing (500020.BSE)
# {'Global Quote': {'01. symbol': '500020.BSE', '02. open': '95.5500', '03. high': '95.6000', '04. low': '88.5500', '05. price': '90.7000', '06. volume': '801873', '07. latest trading day': '2021-12-20', '08. previous close': '96.5500', '09. change': '-5.8500', '10. change percent': '-6.0590%'}}
# 500020.BSE 90.7000
# Alpha Vantage allows only 5 calls a minute. So, wait...
# (6) Getting data for: BPCL (BPCL.BSE)
# {'Global Quote': {'01. symbol': 'BPCL.BSE', '02. open': '380.0000', '03. high': '380.0000', '04. low': '359.1000', '05. price': '360.1000', '06. volume': '659073', '07. latest trading day': '2021-12-20', '08. previous close': '384.8000', '09. change': '-24.7000', '10. change percent': '-6.4189%'}}
# BPCL.BSE 360.1000
# (7) Getting data for: HFCL (500183.BSE)
# {'Global Quote': {'01. symbol': '500183.BSE', '02. open': '79.1000', '03. high': '79.2000', '04. low': '72.8500', '05. price': '73.8000', '06. volume': '3430614', '07. latest trading day': '2021-12-20', '08. previous close': '80.2500', '09. change': '-6.4500', '10. change percent': '-8.0374%'}}
# 500183.BSE 73.8000
# (8) Getting data for: IEX (540750.BSE)
# {'Global Quote': {'01. symbol': '540750.BSE', '02. open': '250.0000', '03. high': '250.6500', '04. low': '235.1500', '05. price': '238.6000', '06. volume': '2793182', '07. latest trading day': '2021-12-20', '08. previous close': '256.1500', '09. change': '-17.5500', '10. change percent': '-6.8515%'}}
# 540750.BSE 238.6000
# (9) Getting data for: Infosys (INFY.BSE)
# {'Global Quote': {'01. symbol': 'INFY.BSE', '02. open': '1806.0000', '03. high': '1830.0000', '04. low': '1786.7500', '05. price': '1798.7000', '06. volume': '314664', '07. latest trading day': '2021-12-20', '08. previous close': '1821.7000', '09. change': '-23.0000', '10. change percent': '-1.2626%'}}
# INFY.BSE 1798.7000
# (10) Getting data for: IRCON (541956.BSE)
# {'Global Quote': {'01. symbol': '541956.BSE', '02. open': '46.0000', '03. high': '46.0000', '04. low': '43.9000', '05. price': '44.4500', '06. volume': '526408', '07. latest trading day': '2021-12-20', '08. previous close': '45.0500', '09. change': '-0.6000', '10. change percent': '-1.3319%'}}
# 541956.BSE 44.4500
# Alpha Vantage allows only 5 calls a minute. So, wait...
# (11) Getting data for: IRCTC (542830.BSE)
# {'Global Quote': {'01. symbol': '542830.BSE', '02. open': '808.0000', '03. high': '824.3000', '04. low': '781.0000', '05. price': '794.4000', '06. volume': '735087', '07. latest trading day': '2021-12-20', '08. previous close': '832.2000', '09. change': '-37.8000', '10. change percent': '-4.5422%'}}
# 542830.BSE 794.4000
# (12) Getting data for: JSW Steel (JSWSTEEL.BSE)
# {'Global Quote': {'01. symbol': 'JSWSTEEL.BSE', '02. open': '656.0000', '03. high': '656.0000', '04. low': '630.3500', '05. price': '643.6500', '06. volume': '291542', '07. latest trading day': '2021-12-20', '08. previous close': '659.9000', '09. change': '-16.2500', '10. change percent': '-2.4625%'}}
# JSWSTEEL.BSE 643.6500
# (13) Getting data for: Laurus Labs (540222.BSE)
# {'Global Quote': {'01. symbol': '540222.BSE', '02. open': '489.5500', '03. high': '491.1500', '04. low': '468.0000', '05. price': '479.1000', '06. volume': '291461', '07. latest trading day': '2021-12-20', '08. previous close': '497.6000', '09. change': '-18.5000', '10. change percent': '-3.7178%'}}
# 540222.BSE 479.1000
# (14) Getting data for: MHRIL (MHRIL.BSE)
# {'Global Quote': {'01. symbol': 'MHRIL.BSE', '02. open': '198.0500', '03. high': '198.1000', '04. low': '191.2000', '05. price': '192.8000', '06. volume': '28942', '07. latest trading day': '2021-12-20', '08. previous close': '198.7000', '09. change': '-5.9000', '10. change percent': '-2.9693%'}}
# MHRIL.BSE 192.8000
# (15) Getting data for: Minda Industries (532539.BSE)
# {'Global Quote': {'01. symbol': '532539.BSE', '02. open': '1043.9000', '03. high': '1055.1500', '04. low': '978.3000', '05. price': '1048.8500', '06. volume': '64964', '07. latest trading day': '2021-12-20', '08. previous close': '1047.0500', '09. change': '1.8000', '10. change percent': '0.1719%'}}
# 532539.BSE 1048.8500
# Alpha Vantage allows only 5 calls a minute. So, wait...
# (16) Getting data for: Motherson Sumi (517334.BSE)
# {'Global Quote': {'01. symbol': '517334.BSE', '02. open': '209.0000', '03. high': '210.0500', '04. low': '196.2000', '05. price': '201.7500', '06. volume': '665426', '07. latest trading day': '2021-12-20', '08. previous close': '212.4500', '09. change': '-10.7000', '10. change percent': '-5.0365%'}}
# 517334.BSE 201.7500
# (17) Getting data for: Nestle India (NESTLEIND.BSE)
# {'Global Quote': {'01. symbol': 'NESTLEIND.BSE', '02. open': '19074.9492', '03. high': '19254.0000', '04. low': '18606.3008', '05. price': '18893.6992', '06. volume': '1988', '07. latest trading day': '2021-12-20', '08. previous close': '19055.5508', '09. change': '-161.8516', '10. change percent': '-0.8494%'}}
# NESTLEIND.BSE 18893.6992
# (18) Getting data for: Pidilite Industries (500331.BSE)
# {'Global Quote': {'01. symbol': '500331.BSE', '02. open': '2371.3000', '03. high': '2415.2000', '04. low': '2327.4000', '05. price': '2405.2500', '06. volume': '50026', '07. latest trading day': '2021-12-20', '08. previous close': '2393.1500', '09. change': '12.1000', '10. change percent': '0.5056%'}}
# 500331.BSE 2405.2500
# (19) Getting data for: Polycab India Ltd. (542652.BSE)
# {'Global Quote': {'01. symbol': '542652.BSE', '02. open': '2300.0000', '03. high': '2300.0000', '04. low': '2206.1500', '05. price': '2281.9000', '06. volume': '33426', '07. latest trading day': '2021-12-20', '08. previous close': '2324.5000', '09. change': '-42.6000', '10. change percent': '-1.8327%'}}
# 542652.BSE 2281.9000
# (20) Getting data for: Shree Renuka Sugar (532670.BSE)
# {'Global Quote': {'01. symbol': '532670.BSE', '02. open': '28.5000', '03. high': '28.8000', '04. low': '28.2000', '05. price': '28.2000', '06. volume': '1377932', '07. latest trading day': '2021-12-20', '08. previous close': '29.6500', '09. change': '-1.4500', '10. change percent': '-4.8904%'}}
# 532670.BSE 28.2000
# Alpha Vantage allows only 5 calls a minute. So, wait...
# (21) Getting data for: Tata ELXSI (500408.BSE)
# {'Global Quote': {'01. symbol': '500408.BSE', '02. open': '5625.0000', '03. high': '5704.1500', '04. low': '5342.4500', '05. price': '5435.2000', '06. volume': '43096', '07. latest trading day': '2021-12-20', '08. previous close': '5733.9500', '09. change': '-298.7500', '10. change percent': '-5.2102%'}}
# 500408.BSE 5435.2000
# (22) Getting data for: Tata Power (500400.BSE)
# {'Global Quote': {'01. symbol': '500400.BSE', '02. open': '210.6500', '03. high': '211.8500', '04. low': '202.8000', '05. price': '209.1000', '06. volume': '6291941', '07. latest trading day': '2021-12-20', '08. previous close': '215.8000', '09. change': '-6.7000', '10. change percent': '-3.1047%'}}
# 500400.BSE 209.1000
# (23) Getting data for: Tata Steel (TATASTEEL.BSE)
# {'Global Quote': {'01. symbol': 'TATASTEEL.BSE', '02. open': '1120.0000', '03. high': '1120.0000', '04. low': '1066.3500', '05. price': '1072.9500', '06. volume': '419294', '07. latest trading day': '2021-12-20', '08. previous close': '1131.8500', '09. change': '-58.9000', '10. change percent': '-5.2039%'}}
# TATASTEEL.BSE 1072.9500
# (24) Getting data for: Trident (TRIDENT.BSE)
# {'Global Quote': {'01. symbol': 'TRIDENT.BSE', '02. open': '52.3500', '03. high': '53.0000', '04. low': '52.1500', '05. price': '52.1500', '06. volume': '1450158', '07. latest trading day': '2021-12-20', '08. previous close': '54.8500', '09. change': '-2.7000', '10. change percent': '-4.9225%'}}
# TRIDENT.BSE 52.1500
# (25) Getting data for: SBI Cards (SBICARD.BSE)
# {'Global Quote': {'01. symbol': 'SBICARD.BSE', '02. open': '895.0000', '03. high': '896.0000', '04. low': '860.0500', '05. price': '868.6000', '06. volume': '334452', '07. latest trading day': '2021-12-20', '08. previous close': '904.9000', '09. change': '-36.3000', '10. change percent': '-4.0115%'}}
# SBICARD.BSE 868.6000
# Alpha Vantage allows only 5 calls a minute. So, wait...
# (26) Getting data for: Reliance Power (RPOWER.BSE)
# {'Global Quote': {'01. symbol': 'RPOWER.BSE', '02. open': '13.0000', '03. high': '13.0000', '04. low': '12.4500', '05. price': '12.4900', '06. volume': '2955736', '07. latest trading day': '2021-12-20', '08. previous close': '13.1000', '09. change': '-0.6100', '10. change percent': '-4.6565%'}}
# RPOWER.BSE 12.4900
# (27) Getting data for: Jai Corp (JAICORPLTD.BSE)
# {'Global Quote': {'01. symbol': 'JAICORPLTD.BSE', '02. open': '122.0000', '03. high': '122.0000', '04. low': '114.6500', '05. price': '115.6000', '06. volume': '174559', '07. latest trading day': '2021-12-20', '08. previous close': '122.3500', '09. change': '-6.7500', '10. change percent': '-5.5170%'}}
# JAICORPLTD.BSE 115.6000
# (28) Getting data for: CSB Bank Ltd (542867.BSE)
# {'Global Quote': {'01. symbol': '542867.BSE', '02. open': '257.0000', '03. high': '257.0000', '04. low': '235.0500', '05. price': '237.1000', '06. volume': '7962', '07. latest trading day': '2021-12-20', '08. previous close': '256.5000', '09. change': '-19.4000', '10. change percent': '-7.5634%'}}
# 542867.BSE 237.1000
# (29) Getting data for: RVNL (542649.BSE)
# {'Global Quote': {'01. symbol': '542649.BSE', '02. open': '34.0000', '03. high': '34.1000', '04. low': '32.8000', '05. price': '33.3000', '06. volume': '666220', '07. latest trading day': '2021-12-20', '08. previous close': '34.2500', '09. change': '-0.9500', '10. change percent': '-2.7737%'}}
# 542649.BSE 33.3000
# (30) Getting data for: TTK Prestige Ltd. (517506.BSE)
# {'Global Quote': {'01. symbol': '517506.BSE', '02. open': '986.0000', '03. high': '994.3000', '04. low': '943.0000', '05. price': '952.1000', '06. volume': '27347', '07. latest trading day': '2021-12-20', '08. previous close': '1005.4000', '09. change': '-53.3000', '10. change percent': '-5.3014%'}}
# 517506.BSE 952.1000
# Alpha Vantage allows only 5 calls a minute. So, wait...
# [{'company': 'Affle India Ltd.', 'symbol': '542752.BSE', 'date': '2021-12-20', 'price': '1057.4000'}, {'company': 'Amara Raja Batteries', 'symbol': 'AMARAJABAT.BSE', 'date': '2021-12-20', 'price': '591.5000'}, {'company': 'Ashoka Buildcon', 'symbol': '533271.BSE', 'date': '2021-12-20', 'price': '89.0500'}, {'company': 'Asian Paints', 'symbol': 'ASIANPAINT.BSE', 'date': '2021-12-20', 'price': '3240.0500'}, {'company': 'Bombay Dyeing', 'symbol': '500020.BSE', 'date': '2021-12-20', 'price': '90.7000'}, {'company': 'BPCL', 'symbol': 'BPCL.BSE', 'date': '2021-12-20', 'price': '360.1000'}, {'company': 'HFCL', 'symbol': '500183.BSE', 'date': '2021-12-20', 'price': '73.8000'}, {'company': 'IEX', 'symbol': '540750.BSE', 'date': '2021-12-20', 'price': '238.6000'}, {'company': 'Infosys', 'symbol': 'INFY.BSE', 'date': '2021-12-20', 'price': '1798.7000'}, {'company': 'IRCON', 'symbol': '541956.BSE', 'date': '2021-12-20', 'price': '44.4500'}, {'company': 'IRCTC', 'symbol': '542830.BSE', 'date': '2021-12-20', 'price': '794.4000'}, {'company': 'JSW Steel', 'symbol': 'JSWSTEEL.BSE', 'date': '2021-12-20', 'price': '643.6500'}, {'company': 'Laurus Labs', 'symbol': '540222.BSE', 'date': '2021-12-20', 'price': '479.1000'}, {'company': 'MHRIL', 'symbol': 'MHRIL.BSE', 'date': '2021-12-20', 'price': '192.8000'}, {'company': 'Minda Industries', 'symbol': '532539.BSE', 'date': '2021-12-20', 'price': '1048.8500'}, {'company': 'Motherson Sumi', 'symbol': '517334.BSE', 'date': '2021-12-20', 'price': '201.7500'}, {'company': 'Nestle India', 'symbol': 'NESTLEIND.BSE', 'date': '2021-12-20', 'price': '18893.6992'}, {'company': 'Pidilite Industries', 'symbol': '500331.BSE', 'date': '2021-12-20', 'price': '2405.2500'}, {'company': 'Polycab India Ltd.', 'symbol': '542652.BSE', 'date': '2021-12-20', 'price': '2281.9000'}, {'company': 'Shree Renuka Sugar', 'symbol': '532670.BSE', 'date': '2021-12-20', 'price': '28.2000'}, {'company': 'Tata ELXSI', 'symbol': '500408.BSE', 'date': '2021-12-20', 'price': '5435.2000'}, {'company': 'Tata Power', 'symbol': '500400.BSE', 'date': '2021-12-20', 'price': '209.1000'}, {'company': 'Tata Steel', 'symbol': 'TATASTEEL.BSE', 'date': '2021-12-20', 'price': '1072.9500'}, {'company': 'Trident', 'symbol': 'TRIDENT.BSE', 'date': '2021-12-20', 'price': '52.1500'}, {'company': 'SBI Cards', 'symbol': 'SBICARD.BSE', 'date': '2021-12-20', 'price': '868.6000'}, {'company': 'Reliance Power', 'symbol': 'RPOWER.BSE', 'date': '2021-12-20', 'price': '12.4900'}, {'company': 'Jai Corp', 'symbol': 'JAICORPLTD.BSE', 'date': '2021-12-20', 'price': '115.6000'}, {'company': 'CSB Bank Ltd', 'symbol': '542867.BSE', 'date': '2021-12-20', 'price': '237.1000'}, {'company': 'RVNL', 'symbol': '542649.BSE', 'date': '2021-12-20', 'price': '33.3000'}, {'company': 'TTK Prestige Ltd.', 'symbol': '517506.BSE', 'date': '2021-12-20', 'price': '952.1000'}]
